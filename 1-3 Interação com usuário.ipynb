# %% [markdown]
# Visualização de Variáveis e textos

# %%
print('conhecendo o comando print')

x = 8
print('x')
# Out:
# conhecendo o comando print
# x

# %%
y = 10
soma = x + y
print(soma)
# Out:
# 18

# %%
nome = "Richard de carvalho"
print(nome)
# Out:
# Richard de carvalho

# %% [markdown]
# concatenação

# %%
x = 5
print('O valor de x é', x)
# Out:
# o valor de x é 5

# %%
print('O valor de x é', x, 'e o dobro é', x * 2)
# Out:
# O valor de x é 5 e o dobro é 10

# %%
print('eu,', nome, 'tirei', x, 'na prova de Python')
# Out:
# eu, Richard de carvalho tirei 5 na prova de Python

# %%
y = 10; z = 20 + x - y
print('declarar varias variaveis na mesma linha', y, z)
# Out:
# declarar varias variaveis na mesma linha 10 15

# %% [markdown]
# Type

# %%
x = 10
type(x)
print('x', type(x))

nome = 'Richard'
print('nome', type(nome))

num = '100'
num_convert = int(num)   # Converter variável
print('num', type(num))
print('num_conver', type(num_convert))

num_float = float(num)
print('num_float', num_float)
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_conver <class 'int'>
# num_float 100.0

# %% [markdown]
# Input
#
# *   Armazenar a informação digitada pelo usuário em uma variável
# *   O dado armazenado sempre será um texto

# %%
Nome = input('Digite o nome do usuário ')  # aguarde o usuário digitar algo
print(nome)
# Out:
# Digite o nome do usuário Richard
# Richard

# %%
valor = input('digite a nota ')

print(nome, 'sua nota foi', valor)
# Out:
# digite a nota 10
# Richard sua nota foi 10

# %%
valor = input('digite o valor do produto: ')
print(valor)
# Out:
# digite o valor do produto: 4000
# 4000

# %%
desconto = valor - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-30-2171237004.py in <cell line: 0>()
# ----> 1 desconto = valor - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
Valor_convet = int(valor)       # Usado para quando existem varios valores no codigo
desconto = Valor_convet - 1000
print(desconto)
# Out:
# 3000

# %%
desconto = int(valor) - 1000   # Usado para quando existe so uma linha de valores no codigo
print(desconto)
# Out:
# 3000
